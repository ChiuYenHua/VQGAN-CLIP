# %% [markdown]
# <a href="https://colab.research.google.com/github/ChiuYenHua/VQGAN-CLIP/blob/main/DEEPDREAM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/gordicaleksa/pytorch-deepdream.git
# Out:
# Cloning into 'pytorch-deepdream'...
# remote: Enumerating objects: 492, done.
# remote: Counting objects: 100% (125/125), done.
# remote: Compressing objects: 100% (76/76), done.
# remote: Total 492 (delta 65), reused 99 (delta 45), pack-reused 367
# Receiving objects: 100% (492/492), 44.27 MiB | 14.10 MiB/s, done.
# Resolving deltas: 100% (246/246), done.

# %%
# !python /content/pytorch-deepdream/deepdream.py --input '/content/IMG_3615.jpg' --create_ouroboros --ouroboros_length 300
# Out:
# Creating a 300-frame Ouroboros video from IMG_3615.jpg, via VGG16_EXPERIMENTAL model.
# Using ZOOM_ROTATE for the frame transform
# Using pretrained weights = IMAGENET
# Using model layers = ['relu4_3']
# Video output width = 3200
# fps = 30
# **************************************************
#
# Ouroboros iteration 1.
# /usr/local/lib/python3.7/dist-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Saved ouroboros frame to: pytorch-deepdream/data/out-videos/VGG16_EXPERIMENTAL_IMAGENET/000000.jpg
#
# Ouroboros iteration 2.
# Saved ouroboros frame to: pytorch-deepdream/data/out-videos/VGG16_EXPERIMENTAL_IMAGENET/000001.jpg
#
# Ouroboros iteration 3.
# Saved ouroboros frame to: pytorch-deepdream/data/out-videos/VGG16_EXPERIMENTAL_IMAGENET/000002.jpg
#
# ...
